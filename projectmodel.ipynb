# %%
# tf import
import tensorflow as tf

# %%
# keras import
from tensorflow import keras

# %%
# run keras
import keras as kr
# Out:
# Using TensorFlow backend.

# %%
# split the mnist data into train and test
(train_img,train_label),(test_img,test_label) = keras.datasets.mnist.load_data()
 
# reshape and scale the data
train_img = train_img.reshape([-1, 28, 28, 1])
test_img = test_img.reshape([-1, 28, 28, 1])
train_img = train_img/255.0
test_img = test_img/255.0
 
# convert class vectors to binary class matrices --> one-hot encoding
train_label = keras.utils.to_categorical(train_label)
test_label = keras.utils.to_categorical(test_label)

# %%
# our model
model = keras.Sequential([
    keras.layers.Conv2D(32, (5, 5), padding="same", input_shape=[28, 28, 1]),
    keras.layers.MaxPool2D((2,2)),
    keras.layers.Conv2D(64, (5, 5), padding="same"),
    keras.layers.MaxPool2D((2,2)),
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(10, activation='softmax')
])
# compile to show accuracy of each epoch
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# 7 iterations to calculate accuracy
model.fit(train_img,train_label, validation_data=(test_img,test_label), epochs=7)
test_loss,test_acc = model.evaluate(test_img, test_label)
# show us the accuracy
print('Test accuracy:', test_acc)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/7
# 60000/60000 [==============================] - 117s 2ms/sample - loss: 0.1154 - accuracy: 0.9643 - val_loss: 0.0394 - val_accuracy: 0.9863
# Epoch 2/7
# 60000/60000 [==============================] - 116s 2ms/sample - loss: 0.0558 - accuracy: 0.9835 - val_loss: 0.0500 - val_accuracy: 0.9855
# Epoch 3/7
# 60000/60000 [==============================] - 118s 2ms/sample - loss: 0.0418 - accuracy: 0.9877 - val_loss: 0.0409 - val_accuracy: 0.9887
# Epoch 4/7
# 60000/60000 [==============================] - 117s 2ms/sample - loss: 0.0410 - accuracy: 0.9889 - val_loss: 0.0533 - val_accuracy: 0.9883
# Epoch 5/7
# 60000/60000 [==============================] - 117s 2ms/sample - loss: 0.0389 - accuracy: 0.9897 - val_loss: 0.0618 - val_accuracy: 0.9862
# Epoch 6/7
# 60000/60000 [==============================] - 119s 2ms/sample - loss: 0.0349 - accuracy: 0.9913 - val_loss: 0.0888 - val_accuracy: 0.9840
# Epoch 7/7
# 60000/60000 [==============================] - 117s 2ms/sample - loss: 0.0365 - accuracy: 0.9919 - val_loss: 0.0855 - val_accuracy: 0.9861
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Test accuracy: 0.9861

# %%
# view model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        832
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 64)        51264
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              3212288
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 3,274,634
# Trainable params: 3,274,634
# Non-trainable params: 0
# _________________________________________________________________
